# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import requests

# %%
browser = webdriver.Chrome(r'C:\Users\newzion tt Ltd\Downloads\chromedriver_win32\chromedriver.exe')
browser.get('https://linkedin.com')
email = browser.find_element_by_name('session_key')
email.send_keys('idanielnwokocha@gmail.com')
password = browser.find_element_by_name('session_password')
password.send_keys('nwokocha')
browser.find_element_by_css_selector('#main-content > section.section.min-h-\[560px\].flex-nowrap.pt-\[40px\].babybear\:flex-col.babybear\:min-h-\[0\].babybear\:px-mobile-container-padding.babybear\:pt-\[24px\] > div > div > form > div.flex.justify-between.sign-in-form__footer--full-width > button').click()
#browser.implicitly_wait(5)
browser.get('https://www.linkedin.com/in/dipoawojide/recent-activity/all')
page = browser.page_source
# Out:
# <ipython-input-36-b8f9059dc7f1>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   browser = webdriver.Chrome(r'C:\Users\newzion tt Ltd\Downloads\chromedriver_win32\chromedriver.exe')
# <ipython-input-36-b8f9059dc7f1>:3: DeprecationWarning: find_element_by_name is deprecated. Please use find_element(by=By.NAME, value=name) instead
#   email = browser.find_element_by_name('session_key')
# <ipython-input-36-b8f9059dc7f1>:5: DeprecationWarning: find_element_by_name is deprecated. Please use find_element(by=By.NAME, value=name) instead
#   password = browser.find_element_by_name('session_password')
# <ipython-input-36-b8f9059dc7f1>:7: DeprecationWarning: find_element_by_css_selector is deprecated. Please use find_element(by=By.CSS_SELECTOR, value=css_selector) instead
# ...

# %%
soup = BeautifulSoup(page, 'lxml')
listed = soup.find_all(class_ = 'profile-creator-shared-feed-update__container')
looped = []
likes = soup.find_all(class_ = 't-black--light display-flex social-details-social-counts__count-value t-12 hoverable-link-text')
len(likes)
# Out:
# 5

# %%
print(listed)
# Out:
# [<li class="profile-creator-shared-feed-update__container">
# <div>
# <div class="relative">
# <div class="profile-creator-shared-feed-update__anchor"></div>
# <div class="feed-shared-update-v2 feed-shared-update-v2--minimal-padding full-height relative feed-shared-update-v2--e2e artdeco-card" data-urn="urn:li:activity:7061445040669143040" id="ember68">
# <div>
# <div role="status">
# <!-- --> </div>
# <h2 class="visually-hidden">
#               Feed post
#           </h2>
# <div class="update-components-actor display-flex update-components-actor--with-control-menu">
# <!-- -->
# ...

# %%
len(looped)
# Out:
# 20
